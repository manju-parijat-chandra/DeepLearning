# %%
import numpy as np
import pandas as pd
# import time
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from keras import Sequential
from keras.layers import Dense

import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../../DataBox/Social_Network_Ads.csv')

# %%
df = df[['Age','EstimatedSalary','Purchased']]

X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

X_scaled.shape
# Out:
# (400, 2)

# %%
model = Sequential()

model.add(Dense(10,activation='relu',input_dim=2))
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
# Out:
# C:\Users\parij\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='binary_crossentropy',metrics=['accuracy'])
#start = time.time()
history = model.fit(X_scaled,y,epochs=10,batch_size=400,validation_split=0.2) # Batch Size = No of rows In Data 
#print(time.time() - start)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 961ms/step - accuracy: 0.4469 - loss: 0.7364 - val_accuracy: 0.6750 - val_loss: 0.6463
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.4750 - loss: 0.7191 - val_accuracy: 0.6875 - val_loss: 0.6468
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.4969 - loss: 0.7072 - val_accuracy: 0.7125 - val_loss: 0.6471
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.5156 - loss: 0.6977 - val_accuracy: 0.7000 - val_loss: 0.6475
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5312 - loss: 0.6895 - val_accuracy: 0.7250 - val_loss: 0.6478
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.5531 - loss: 0.6822 - val_accuracy: 0.7750 - val_loss: 0.6480
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5781 - loss: 0.6756 - val_accuracy: 0.7750 - val_loss: 0.6482
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6125 - loss: 0.6695 - val_accuracy: 0.8000 - val_loss: 0.6483
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.6156 - loss: 0.6637 - val_accuracy: 0.8500 - val_loss: 0.6484
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6500 - loss: 0.6582 - val_accuracy: 0.8625 - val_loss: 0.6486

# %%
plt.plot(history.history['loss'])
