# %%
import numpy as np
import pandas as pd
# import time
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from keras import Sequential
from keras.layers import Dense

import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../../DataBox/Social_Network_Ads.csv')

# %%
df = df[['Age','EstimatedSalary','Purchased']]

X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

X_scaled.shape
# Out:
# (400, 2)

# %%
model = Sequential()

model.add(Dense(10,activation='relu',input_dim=2))
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
# Out:
# C:\Users\parij\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='binary_crossentropy',metrics=['accuracy'])
#start = time.time()
history = model.fit(X_scaled,y,epochs=10,batch_size=50,validation_split=0.2) # Batch Size less than No of Rows -> No of Row / batch size -> Batch GD
#print(time.time() - start)
# Out:
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.5188 - loss: 0.7021 - val_accuracy: 0.7375 - val_loss: 0.6247
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5813 - loss: 0.6773 - val_accuracy: 0.8000 - val_loss: 0.6211
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6375 - loss: 0.6618 - val_accuracy: 0.8000 - val_loss: 0.6199
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6719 - loss: 0.6485 - val_accuracy: 0.8125 - val_loss: 0.6177
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7312 - loss: 0.6364 - val_accuracy: 0.8125 - val_loss: 0.6155
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7937 - loss: 0.6252 - val_accuracy: 0.8000 - val_loss: 0.6120
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8406 - loss: 0.6145 - val_accuracy: 0.8000 - val_loss: 0.6074
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8656 - loss: 0.6041 - val_accuracy: 0.8250 - val_loss: 0.6052
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8687 - loss: 0.5943 - val_accuracy: 0.8250 - val_loss: 0.5998
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8656 - loss: 0.5846 - val_accuracy: 0.8250 - val_loss: 0.5937

# %%
plt.plot(history.history['loss'])
